# %%
import pandas as pd
import numpy as np
import math
import os
from sqlalchemy import create_engine
import geopandas as gp
import json

from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar, NumeralTickFormatter
from bokeh.palettes import brewer

from bokeh.io.doc import curdoc
from bokeh.models import Slider, HoverTool, Select
from bokeh.layouts import widgetbox, row, column

# %%
# %load_ext dotenv
# %dotenv ../.env
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
cnx = create_engine(os.getenv('EDMDB'))

# %% [markdown]
# Test connection

# %%
df2000 = pd.read_sql_query('SELECT * FROM gep690.census_2000', cnx)
df2000.head()
# Out:
#      id                                               geom borocode  \
# 0  1330  0106000020D70800000100000001030000000100000064...       SI
# 1  1781  0106000020D7080000010000000103000000010000002A...       SI
# 2    38  0106000020D70800000100000001030000000100000013...       BX
# 3   196  0106000020D70800000100000001030000000100000020...       BK
# 4  1418  0106000020D7080000010000000103000000010000002C...       QN
#
#   boro_ct2000      boro_name cdeligibil  ct2000 ctlabel ntacode  \
# 0     5029104  Staten Island          I  029104  291.04    SI05
# 1     5008900  Staten Island          I  008900      89    SI22
# 2     2025000          Bronx          I  025000     250    BX49
# 3     3027101       Brooklyn          E  027101  271.01    BK61
# 4     4056700         Queens          I  056700     567    QN19
#
#                                      ntaname  ... median_hh_income  \
# 0          New Springville-Bloomfield-Travis  ...            62260
# 1  West New Brighton-New Brighton-St. George  ...                0
# 2                             Pelham Parkway  ...            38854
# 3                        Crown Heights North  ...            26686
# 4                                   Glendale  ...            51544
#
#    tot_housing_units  owner_occupied_housing_units  pct_owner_occupied  \
# 0               2355                          1658                70.4
# 1                  0                             0                 0.0
# 2                996                           415                41.7
# 3                606                            94                15.5
# 4               1502                           904                60.2
#
#    median_housing_value  in_labor_force_16up  in_labor_force_unemployed_16up  \
# 0                187500                 3705                             286
# 1                     0                    0                               0
# 2                194100                  998                              45
# 3                182800                  528                              30
# 4                195300                 2119                             117
#
#    pct_unemployed_16up  pct_below_poverty_level  pct_educated
# 0                  5.3                    7.220        25.687
# 1                  0.0                    0.000         0.000
# 2                  2.3                    6.673        24.171
# 3                  2.3                   28.331        12.138
# 4                  3.5                    9.611        19.760
#
# [5 rows x 24 columns]

# %% [markdown]
# Generate a report of rows with zeros in the median household income

# %%
zero_mi_2000 = df2000.loc[df2000['median_hh_income'] == 0]
zero_mi_2000 = zero_mi_2000[~zero_mi_2000['ntaname'].str.contains('park-')]
zero_mi_2000 = zero_mi_2000[~zero_mi_2000['ntaname'].str.contains('Airport')]
zero_mi_2000
# Out:
#         id                                               geom borocode  \
# 1     1781  0106000020D7080000010000000103000000010000002A...       SI
# 46    1473  0106000020D7080000010000000103000000010000001E...       BK
# 132    667  0106000020D70800000100000001030000000100000019...       BX
# 235   1716  0106000020D70800000100000001030000000100000041...       BX
# 295    433  0106000020D70800000100000001030000000100000024...       QN
# 352   1503  0106000020D708000001000000010300000001000000A9...       BX
# 459   1688  0106000020D70800000100000001030000000100000064...       QN
# 661   1478  0106000020D70800000100000001030000000100000073...       MN
# 720   1655  0106000020D70800000100000001030000000100000021...       BX
# 2169                  0                             0                 0.0
# 2192                  0                             0                 0.0
#
#       median_housing_value  in_labor_force_16up  \
# 1                        0                    0
# 46                       0                    0
# 132                      0                    0
# 235                      0                    0
# 295                      0                    0
# 352                      0                    4
# 459                      0                    0
# 661                      0                    0
# 720                      0                    0
# 790                      0                    0
# 827                      0                    0
# 837                      0                    0
# 855                      0                    0
# 1030                     0                    0
# 1095                     0                    0
# 1650                     0                    0
# 1978                     0                    0
# 2169                     0                    0
# 2192                     0                    0
#
#       in_labor_force_unemployed_16up  pct_unemployed_16up  \
# 1                                  0                  0.0
# 46                                 0                  0.0
# 132                                0                  0.0
# 235                                0                  0.0
# 295                                0                  0.0
# 352                                0                  0.0
# 459                                0                  0.0
# 661                                0                  0.0
# 720                                0                  0.0
# 790                                0                  0.0
# 827                                0                  0.0
# 837                                0                  0.0
# 855                                0                  0.0
# 1030                               0                  0.0
# 1095                               0                  0.0
# 1650                               0                  0.0
# 1978                               0                  0.0
# 2169                               0                  0.0
# 2192                               0                  0.0
#
#       pct_below_poverty_level  pct_educated
# 1                       0.000         0.000
# 46                      0.000         0.000
# 132                     0.000         0.000
# 235                     0.000         0.000
# 295                     0.000         0.977
# 352                    55.696        11.914
# 459                     0.000         0.000
# 661                     0.000         0.000
# 720                     0.000         0.000
# 790                     0.000         0.000
# 827                     0.000         0.000
# 837                     0.000         0.000
# 855                     0.000         0.000
# 1030                    0.000         0.952
# 1095                    0.000         0.000
# 1650                    0.000         0.000
# 1978                    0.000         0.000
# 2169                    0.000         7.856
# 2192                    0.000         0.000
#
# [19 rows x 24 columns]

# %%
nyc_2000 = gp.read_file('../Shapefiles/NYC_Census_Tracts_2000.geojson')
nyc_2000.crs = {'init': 'epsg:2263'}
nyc_2000.sort_values(by=['boro_ct200'])
nyc_2000.set_geometry('geometry')
nyc_2000.head()
# Out:
#   boro_code boro_ct200  boro_name cdeligibil  ct2000 ctlabel ntacode  \
# 0         1    1009800  Manhattan          I  009800      98    MN19
# 1         1    1010000  Manhattan          I  010000     100    MN19
# 2         1    1019000  Manhattan          E  019000     190    MN11
# 3         1    1020600  Manhattan          E  020600     206    MN03
# 4         1    1021702  Manhattan          E  021702  217.02    MN03
#
#                              ntaname  puma    shape_area   shape_leng  \
# 0            Turtle Bay-East Midtown  3808  1.906016e+06  5534.200060
# 1            Turtle Bay-East Midtown  3808  1.860938e+06  5692.168666
# 2               Central Harlem South  3803  1.117372e+06  4231.826588
# 3  Central Harlem North-Polo Grounds  3803  1.602694e+06  5176.873151
# 4  Central Harlem North-Polo Grounds  3803  4.469939e+05  3338.290909
#
#                                             geometry
# 0  MULTIPOLYGON (((994133.507 214848.898, 994005....
# 1  MULTIPOLYGON (((993108.306 216013.131, 992982....
# 2  MULTIPOLYGON (((999462.778 231690.097, 999336....
# 3  MULTIPOLYGON (((1002020.030 234205.400, 100200...
# 4  MULTIPOLYGON (((998910.797 236510.392, 998785....

# %% [raw]
# nyc_merged = pd.merge(nyc_2000, df2000, on='[boro_ct200, boro_ct2000]', how='left')
# nyc_merged_json = json.loads(nyc_merged.to_json())
# json_data = json.dumps(nyc_merged_json)
